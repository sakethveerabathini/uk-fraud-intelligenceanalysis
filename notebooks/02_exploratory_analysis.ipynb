# %%
# WHY: pandas reads our database and manipulates data
# WHY: sqlite3 connects to our uk_fraud.db database
# WHY: matplotlib is the base chart library
# WHY: seaborn builds on matplotlib — makes 
#      professional statistical charts easily
# WHY: warnings hides unnecessary warning messages
#      that clutter our output

import pandas as pd
import sqlite3
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# WHY: This sets the visual style for ALL charts
# in this notebook — dark grid looks professional
# and is easy to read in reports and dashboards
sns.set_theme(style="darkgrid")
plt.rcParams['figure.figsize'] = (12, 6)
plt.rcParams['font.size'] = 12

# WHY: Connect to our database — all queries
# in this notebook will use this connection
conn = sqlite3.connect('../data/processed/uk_fraud.db')

print("Everything loaded and ready")
print("Connected to uk_fraud.db")
